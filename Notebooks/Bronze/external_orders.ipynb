-- %% [markdown]
-- ### Creating a View for the orders table to be available at Bronze schema

-- %%
CREATE OR REPLACE VIEW retailx.bronze.orders AS
SELECT 
  order_id,
  customer_id,
  order_date,
  Amount as amount
FROM `retailx-onprem`.retail.orders;

-- %%
DESCRIBE retailx.bronze.orders;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>order_id</td><td>bigint</td><td>null</td></tr><tr><td>customer_id</td><td>double</td><td>null</td></tr><tr><td>order_date</td><td>string</td><td>null</td></tr><tr><td>amount</td><td>string</td><td>null</td></tr></tbody></table></div>
